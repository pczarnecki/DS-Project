# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm
import scipy.constants as sp
import DataSetup as DS
import DSProject as SA

# %% [markdown]
# Overall parameters: Using 60 spectral points, block size of 10k, eval-1 training set and eval-2 testing set errors recorded.

# %%
### Linear Regression
results = xr.open_dataset("DS_Linear.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.savefig("60Linear.png", bbox_inches='tight', dpi=600)
plt.show()

# %%
### Ridge Regression
results = xr.open_dataset("DS_Ridge10-5.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.savefig("Ridge10-5.png", bbox_inches='tight', dpi=600)
plt.show()

# %%
### Ridge Regression with an Intercept and only Positive Values
results = xr.open_dataset("DS_Ridge10-5_intercept.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.savefig("Ridge10-5_intercept.png", bbox_inches='tight', dpi=600)
plt.show()

# %%
results = xr.open_dataset("10-5_rerun.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.savefig("Ridge10-5.png", bbox_inches='tight', dpi=600)
plt.show()

# %%
results = xr.open_dataset("10-5_16wn.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.savefig("Ridge10-5.png", bbox_inches='tight', dpi=600)
plt.show()

# %%
results = xr.open_dataset("DS_Ridge10-9.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("10-9_16wn.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("10-9_40wn.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("10-9_20wn_shorterepoch.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("10-9_40wn_shorterepoch.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("10-9_60wn_shorterepoch.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("10-9_100wn_shorterepoch.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("results20T_intercept.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("results40T_intercept.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("results60T_intercept.h5", engine = "netcdf4")

plt.semilogy(results.blocks, results.e_hist[0])
plt.semilogy(results.blocks, results.e_test[0])
plt.legend(["training", "testing"])
plt.xlabel("blocks (x 10,000 iterations)")
plt.ylabel("mean absolute RMSE")
plt.show()

# %%
results = xr.open_dataset("DS_Lasso.h5", engine = "netcdf4")

# %%
plt.semilogy(np.linspace(1, 6, 6), results.train_errors)
plt.semilogy(np.linspace(1, 6, 6), results.test_errors)
plt.legend(["training", "testing"])
x_ticks = ["$10^{-8}$, 152,196", "$10^{-7}$, 133,175", "$10^{-6}$, 50,291", "$10^{-5}$, 5,556", "$10^{-4}$, 75", "$10^{-3}$, 8"]
plt.xticks(np.linspace(1, 6, 6), labels = x_ticks, rotation = 'vertical')

plt.xlabel("(alpha, subset size)")
plt.ylabel("absolute RMSE")
plt.savefig("LASSO.png", bbox_inches='tight', dpi=600)
plt.show()

# %%
#set up data
ref_input = "/data/robertp/CKDMIP_LBL/evaluation1/lw_fluxes/ckdmip_evaluation1_lw_fluxes_present.h5"
spec_input = ["/data/pc2943/spectral_fluxes_1-10.h5", "/data/pc2943/spectral_fluxes_11-20.h5",
                                "/data/pc2943/spectral_fluxes_21-30.h5", "/data/pc2943/spectral_fluxes_31-40.h5",
                                "/data/pc2943/spectral_fluxes_41-50.h5"]
specTest_input = ["/data/pc2943/eval2_spectral_fluxes_1-10.h5", "/data/pc2943/eval2_spectral_fluxes_11-20.h5",
                                "/data/pc2943/eval2_spectral_fluxes_21-30.h5", "/data/pc2943/eval2_spectral_fluxes_31-40.h5",
                                "/data/pc2943/eval2_spectral_fluxes_41-50.h5"]
refTest_input = "/data/robertp/CKDMIP_LBL/evaluation2/lw_fluxes/ckdmip_evaluation2_lw_fluxes-4angle_present.h5"

level_array = np.array([0])
level_type = np.array(['f'])


#ref_train, ref_test, spec_train, spec_test = DS.data_setup_train_test(level_array, level_type, spec_input, ref_input, num_train, None)
spec_train, ref_train = DS.data_setup(level_array, level_type, ref_input, spec_input, None)
spec_test, ref_test = DS.data_setup(level_array, level_type, refTest_input, specTest_input, None)

# %%
ns = np.array([20, 40, 60, 100])
#errors = np.zeros((2, len(ns)))
train_cost = np.zeros(len(ns))
test_cost = np.zeros(len(ns))
train_ridge = np.zeros(len(ns))
test_ridge = np.zeros(len(ns))

for i in range(len(ns)):
    results_ridge = xr.open_dataset('10-9_' + str(ns[i]) + 'wn_shorterepoch.h5', engine = 'netcdf4')
    results_linear = xr.open_dataset('results' + str(ns[i]) + 'T_intercept.h5', engine = 'netcdf4')
    train_cost[i] = results_linear.E
    w_final, intercept, q_v, q_tilde = SA.compute_q_tilde(results_linear.S.data, spec_train, ref_train, 1, 50)
    test_error = SA.compute_testing(results_linear.S.data, w_final, intercept, spec_test, ref_test, 1, 50)
    test_cost[i] = test_error
    
    train_ridge[i] = results_ridge.E
    w_final, intercept, q_v, q_tilde = SA.compute_q_tilde(results_ridge.S.data, spec_train, ref_train, 1, 50)
    test_error = SA.compute_testing(results_ridge.S.data, w_final, intercept, spec_test, ref_test, 1, 50)
    test_ridge[i] = test_error

# %%
plt.semilogy(ns, train_cost)
plt.semilogy(ns, test_cost)
plt.xlabel('# of spectral points')
plt.ylabel('absolute RMSE')
plt.title('linear regression')
plt.legend(['training', 'testing'])
plt.savefig("linear_summary.png", bbox_inches='tight', dpi=600)
plt.show()

plt.semilogy(ns, train_ridge)
plt.semilogy(ns, test_ridge)
plt.legend(['training', 'testing'])
plt.xlabel('# of spectral points')
plt.ylabel('absolute RMSE')
plt.title('ridge regression')
plt.savefig("ridge_summary.png", bbox_inches='tight', dpi=600)

plt.show()
